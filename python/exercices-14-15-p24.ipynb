# %% [markdown]
# # Exercice 14 p.24
#
# Karim a obtenu 4 notes en mathématiques ce trimestre :
#
# $$13 ; 9,5 ; 11 \text{ et } 15.$$
#
# En saisissant les instructions dans les cellules ci-dessous (n'oubliez pas de les exécuter : au clavier MAJ+Entrée ou en cliquant sur "Run" ci-dessus), répondre aux questions de l'exercice (que je vous rappelle ci-dessous).
#
# 1. **Stocker ces 4 valeurs dans une liste nommée `notes`.**

# %% [markdown]
# 2. **Afficher la 3e note de Karim.**

# %% [markdown]
# 3. **Ajouter la note $18$ en fin de liste.**

# %% [markdown]
# 4. **Afficher le nombre de valeur de la liste.**

# %% [markdown]
# 5. **Supprimer la note $11$ de la liste.**

# %% [markdown]
# ---

# %% [markdown]
# # Exercice 15 p.24
#
# Lisa participe à un jeu de rôle. Pour que son personnage traverse un pont suspendu, elle doit raliser un test d'adresse à l'aide de 4 dés à 10 faces numérotées de 0 et 9. Elle lance les quatre dés et elle réussit ce test si, et seulement si, au moins un des dés affiche un résultat supérieur ou égal à 7.
#
# *J'ai un peu modifié les questions pour les rendre plus accessibles étant donné que l'on est dans de la (re)découverte des listes en Python.*
#
# 1. **Compléter l'instruction ci-dessous, qui permet de générer un nombre entier aléatoire entre 0 et 9.**

# %%
from random import randint
# on importe la fonction randint depuis le module random pour simuler des tirage aléatoires d'entiers
# randint(a,b) permet de tirer un entier aléatoire entre a et b inclus (a et b entiers)

randint(...,...)

# %% [markdown]
# 2. **Créer une liste `resultat` contenant les résultats des 4 dés de Lisa.**

# %%
resultat=[...]

# %% [markdown]
# 3. **Écrire une instruction qui permette de déterminer si le résultat du premier dé est supérieur ou égal à 7.**
#
# Rappel sur les tests en Python : ![image.png](attachment:image.png)
#
# **Attention :** le premier élément d'une liste est indexé par 0.
#
# Par exemple :

# %%
L = [2,6,7,3]
L[0]
# Out:
# 2

# %% [markdown]
# **Votre réponse dans la cellule ci-dessous :**

# %% [markdown]
# 4. **Compléter l'instruction suivante pour qu'elle permette de déterminer si au moins un des dés de Lisa affiche un résultat supérieur ou égal à 7.**

# %%
... or ... or ... or ...
