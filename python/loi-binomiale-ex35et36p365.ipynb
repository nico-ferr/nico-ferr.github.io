# %% [markdown]
# ## Exercice 35 p.365
#
# On considère une variable aléatoire $X$ qui suit la loi binomiale de paramètres $n=10$ et $p=0,7$.
#
# La fonction `LoiDeProbabilite` ci-dessous renvoie une liste `bino` telle que, pour tout entier naturel $k$, la valeur `bino[k]` est égale à $\operatorname P(X=k)$.
#
# Compléter cette fonction.

# %%
from math import factorial
# On importe la fonction factorial, qui permet de calculer n!

def LoiDeProbabilite():
    bino = 11*[0]
    for k in range(...):
        bino[k] = ...
    return bino

# %% [markdown]
# Faites ensuite un essai en calculant $\operatorname P(X=6)$ à l'aide de la fonction `LoiDeProbabilite` et vérifiez que vous retrouvez le même résultat que dans l'exercice 32 p.364.

# %% [markdown]
# ## Exercice 36 p.365
#
# La fonction Python `binomFRep` ci-dessous permet de calculer $\operatorname P(X\leqslant k)$ lorsque $X$ suit une loi binomiale de paramètres $n$ et $p$.
#
# Compléter cette fonction.

# %%
from math import factorial
# Pas obligatoire ici car on a déjà chargé la fonction factorial
# pour l'exercice précédent, cependant pour coller à l'énoncé de
# cet exercice, j'ai choisi de conserver cette ligne de code

def binomFRep(n, p, k):
    """si la v.a. suit une B(n ,p),
    renvoie P(X <= k)"""
    s = 0
    for i in range(...):
        s = s + factorial(n)/(factorial(i)*factorial(n-i))*...
    return s

# %% [markdown]
# Faites ensuite un essai en calculant $\operatorname P(X\leqslant 16)$, pour $X\equiv \mathscr B(100;0,15)$, à l'aide de la fonction `binomFRep` et vérifiez que vous retrouvez le même résultat que dans l'exercice 31 p.364.
