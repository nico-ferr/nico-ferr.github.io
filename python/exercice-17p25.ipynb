# %% [markdown]
# # Exercice 17 p.25
#
# On considère l'expérience qui consiste à lancer deux dés équilibrés à 6 faces puis à observer la somme de ces deux dés.
#
# 1. **Compléter la fonction suivante pour qu'elle renvoie une liste `L` de 100 sommes obtenues avec des lancers de deux dés.**

# %%
from random import ...

def sommes():
    res=[]
    for k in range(...):
        de1=...
        de2=...
        res.append(...)
    return res

# %% [markdown]
# 2. **Expliquer ce que représente la valeur renvoyée par la fonction Python dont on donne le script ci-dessous quand on donne en argument une liste générée par la fonction de la question** 1.

# %%
def fonction(L):
    S=0
    for k in range(len(L)):
        if L[k]==7:
            S=S+1
    return S/len(L)

# %% [markdown]
# Explication :

# %% [markdown]
# **Faire alors un essai en exécutant le code ci-dessous.**

# %%
liste=sommes()

fonction(liste)
